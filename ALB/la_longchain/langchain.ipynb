# %%
import langchain

# %%
from langchain.llms import OpenAI

# %%
import os
os.environ["OPEN_API_KEY"]=""

# %%
llm=OpenAI(openai_api_key=os.environ["OPEN_API_KEY"],temperature=0.6)

# %%
text="What is the capital of India"

print(llm.predict(text))
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /var/folders/rc/7nlfhs8j0k31f8l7zfxf702h0000gn/T/ipykernel_4127/2739170393.py in <module>
#       1 text="What is the capital of India"
#       2
# ----> 3 print(llm.predict(text))
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     143                 warned = True
#     144                 emit_warning()
# --> 145             return wrapped(*args, **kwargs)
#     146
#     147         if isinstance(obj, type):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/langchain_core/language_models/llms.py in predict(self, text, stop, **kwargs)
#     987         else:
#     988             _stop = list(stop)
# --> 989         return self(text, stop=_stop, **kwargs)
#     990
#     991     @deprecated("0.1.7", alternative="invoke", removal="0.2.0")
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     143                 warned = True
#     144                 emit_warning()
# --> 145             return wrapped(*args, **kwargs)
#     146
#     147         if isinstance(obj, type):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/langchain_core/language_models/llms.py in __call__(self, prompt, stop, callbacks, tags, metadata, **kwargs)
#     946             )
#     947         return (
# --> 948             self.generate(
#     949                 [prompt],
#     950                 stop=stop,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/langchain_core/language_models/llms.py in generate(self, prompts, stop, callbacks, tags, metadata, run_name, **kwargs)
#     696                 )
#     697             ]
# --> 698             output = self._generate_helper(
#     699                 prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     700             )
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/langchain_core/language_models/llms.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     560             for run_manager in run_managers:
#     561                 run_manager.on_llm_error(e, response=LLMResult(generations=[]))
# --> 562             raise e
#     563         flattened_outputs = output.flatten()
#     564         for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/langchain_core/language_models/llms.py in _generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     547         try:
#     548             output = (
# --> 549                 self._generate(
#     550                     prompts,
#     551                     stop=stop,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/langchain_community/llms/openai.py in _generate(self, prompts, stop, run_manager, **kwargs)
#     458                 )
#     459             else:
# --> 460                 response = completion_with_retry(
#     461                     self, prompt=_prompts, run_manager=run_manager, **params
#     462                 )
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/langchain_community/llms/openai.py in completion_with_retry(llm, run_manager, **kwargs)
#     113     """Use tenacity to retry the completion call."""
#     114     if is_openai_v1():
# --> 115         return llm.client.create(**kwargs)
#     116
#     117     retry_decorator = _create_retry_decorator(llm, run_manager=run_manager)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     269                         msg = f"Missing required argument: {quote(missing[0])}"
#     270                 raise TypeError(msg)
# --> 271             return func(*args, **kwargs)
#     272
#     273         return wrapper  # type: ignore
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/openai/resources/completions.py in create(self, model, prompt, best_of, echo, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, seed, stop, stream, suffix, temperature, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     504         timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     505     ) -> Completion | Stream[Completion]:
# --> 506         return self._post(
#     507             "/completions",
#     508             body=maybe_transform(
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/openai/_base_client.py in post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1177             method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1178         )
# -> 1179         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1180
#    1181     def patch(
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/openai/_base_client.py in request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     866         stream_cls: type[_StreamT] | None = None,
#     867     ) -> ResponseT | _StreamT:
# --> 868         return self._request(
#     869             cast_to=cast_to,
#     870             options=options,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     942             if retries > 0 and self._should_retry(err.response):
#     943                 err.response.close()
# --> 944                 return self._retry_request(
#     945                     options,
#     946                     cast_to,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/openai/_base_client.py in _retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     990         time.sleep(timeout)
#     991
# --> 992         return self._request(
#     993             options=options,
#     994             cast_to=cast_to,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     942             if retries > 0 and self._should_retry(err.response):
#     943                 err.response.close()
# --> 944                 return self._retry_request(
#     945                     options,
#     946                     cast_to,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/openai/_base_client.py in _retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     990         time.sleep(timeout)
#     991
# --> 992         return self._request(
#     993             options=options,
#     994             cast_to=cast_to,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     957
#     958             log.debug("Re-raising status error")
# --> 959             raise self._make_status_error_from_response(err.response) from None
#     960
#     961         return self._process_response(
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
